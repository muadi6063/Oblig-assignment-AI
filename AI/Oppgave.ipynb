# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Oppgave 1
Grc_df = pd.read_csv("Grocery_dataset.csv")  # pass på at filen ligger i samme mappe
Grc_df.head(10)    # viser de første 10 radene
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
# Oppgave 2.1
Grc_df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   818
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1439
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Oppgave 2.2
Grc_df = Grc_df.replace(r'^\s*$', np.nan, regex=True)
Grc_df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
# Oppgave 3.1
Grc_df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
# Oppgave 3.2
Grc_df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    1605
# Small     1398
# High       558
# Name: count, dtype: int64

# %%
# Oppgave 3.3
# Finn mest vanlig (maksimum) og minst vanlig (minimum)
most_common = Grc_df['Outlet_Size'].value_counts().idxmax()
least_common = Grc_df['Outlet_Size'].value_counts().idxmin()

print("Mest vanlig Outlet_Size:", most_common)
print("Minst vanlig Outlet_Size:", least_common)
# Out:
# Mest vanlig Outlet_Size: Medium
# Minst vanlig Outlet_Size: High

# %%
# Oppgave 4
Grc_df['Item_Fat_Content'] = Grc_df['Item_Fat_Content'].replace({
    'low fat': 'Low Fat',
    'LF': 'Low Fat',
    'reg': 'Regular'
})

Grc_df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
# Oppgave 5
Grc_new_df = Grc_df.drop(Grc_df.columns[[0, 6]], axis=1)
Grc_new_df.head(10)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0        9.300          Low Fat         0.016047                  Dairy
# 1        5.920          Regular         0.019278            Soft Drinks
# 2       17.500          Low Fat         0.016760                   Meat
# 3       19.200          Regular         0.000000  Fruits and Vegetables
# 4        8.930          Low Fat         0.000000              Household
# 5       10.395          Regular         0.000000           Baking Goods
# 6       13.650          Regular         0.012741            Snack Foods
# 7          NaN          Low Fat         0.127470            Snack Foods
# 8       16.200          Regular         0.016687           Frozen Foods
# 9       19.200          Regular         0.094450           Frozen Foods
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# ...

# %%
# Oppgave 6.1
SupType_1 = Grc_new_df[Grc_new_df['Outlet_Type'] == 'Supermarket Type1']

SupType_2 = Grc_new_df[Grc_new_df['Outlet_Type'] == 'Supermarket Type2']
SupType_1.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  Item_MRP  \
# 0         9.30          Low Fat         0.016047         Dairy  249.8092
# 2        17.50          Low Fat         0.016760          Meat  141.6180
# 4         8.93          Low Fat         0.000000     Household   53.8614
# 6        13.65          Regular         0.012741   Snack Foods   57.6588
# 8        16.20          Regular         0.016687  Frozen Foods   96.9726
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 2                       1999      Medium               Tier 1
# 4                       1987        High               Tier 3
# 6                       1987        High               Tier 3
# 8                       2002         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 2  Supermarket Type1          2097.2700
# ...

# %%
# Oppgave 6.2
SupType_2.head()
# Out:
#     Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 1         5.920          Regular         0.019278         Soft Drinks
# 5        10.395          Regular         0.000000        Baking Goods
# 16       11.800          Low Fat         0.008596  Health and Hygiene
# 31       18.600          Low Fat         0.080829  Health and Hygiene
# 32       18.700          Low Fat         0.000000         Snack Foods
#
#     Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1    48.2692                       2009      Medium               Tier 3
# 5    51.4008                       2009      Medium               Tier 3
# 16  115.3492                       2009      Medium               Tier 3
# 31   96.4436                       2009      Medium               Tier 3
# 32  256.6672                       2009      Medium               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 1   Supermarket Type2           443.4228
# ...

# %%
# Oppgave 7
plt.style.use("ggplot")

fig, axes = plt.subplots(2, 1, figsize=(10,8))

sns.boxplot(x=SupType_1['Item_MRP'], ax=axes[0])
axes[0].set_title('Supermarket Type 1')


sns.boxplot(x=SupType_2['Item_MRP'], ax=axes[1])
axes[1].set_title('Supermarket Type 2')

print(SupType_1['Item_MRP'].describe())
print(SupType_2['Item_MRP'].describe())

# Outlet_Type 1 has a higher median
# Both of them do not have any outliers 
# To see if they have outliers: 
# Lower bound = Q1 - 1.5 × IQR
# Upper bound = Q3 + 1.5 × IQR
# Out:
# count    3328.000000
# mean      142.636458
# std        62.507787
# min        31.955800
# 25%        95.024550
# 50%       144.745700
# 75%       188.031900
# max       266.888400
# Name: Item_MRP, dtype: float64
# count    526.000000
# mean     139.465076
# std       62.816525
# min       31.890000
# 25%       93.569900
# 50%      130.181000
# 75%      184.569350
# max      265.188400
# Name: Item_MRP, dtype: float64

# %%
# Oppgave 8

Grc_Concat_df = pd.concat([SupType_1, SupType_2], ignore_index=True)
Grc_Concat_df_sorted=Grc_Concat_df.sort_values(by='Item_Outlet_Sales')

lowest_sales_row=Grc_Concat_df_sorted.head(1)

print("Outlet_Location_Type with lowest sales:", lowest_sales_row['Outlet_Location_Type'].values[0])
# Out:
# Outlet_Location_Type with lowest sales: Tier 3

# %%
Grc_Concat_df = Grc_Concat_df.set_index(['Outlet_Size', 'Outlet_Location_Type'])
Grc_Concat_df.head()
# Out:
#                                   Item_Weight Item_Fat_Content  \
# Outlet_Size Outlet_Location_Type
# Medium      Tier 1                       9.30          Low Fat
#             Tier 1                      17.50          Low Fat
# High        Tier 3                       8.93          Low Fat
#             Tier 3                      13.65          Regular
# NaN         Tier 2                      16.20          Regular
#
#                                   Item_Visibility     Item_Type  Item_MRP  \
# Outlet_Size Outlet_Location_Type
# Medium      Tier 1                       0.016047         Dairy  249.8092
#             Tier 1                       0.016760          Meat  141.6180
# High        Tier 3                       0.000000     Household   53.8614
#             Tier 3                       0.012741   Snack Foods   57.6588
# NaN         Tier 2                       0.016687  Frozen Foods   96.9726
#
#                                   Outlet_Establishment_Year  \
# ...

# %%
weight_bins = pd.cut(Grc_Concat_df["Item_Weight"], bins=10)

bucket_stats = Grc_Concat_df.groupby(weight_bins)["Item_Weight"].agg(["mean","min","max","count"])
bucket_stats
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_11436\350342293.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bucket_stats = Grc_Concat_df.groupby(weight_bins)["Item_Weight"].agg(["mean","min","max","count"])
#                        mean     min     max  count
# Item_Weight
# (4.538, 6.234]     5.623814   4.555   6.215    253
# (6.234, 7.914]     7.121807   6.235   7.905    476
# (7.914, 9.594]     8.761867   7.930   9.500    450
# (9.594, 11.273]   10.344917   9.600  11.150    362
# (11.273, 12.952]  12.081635  11.300  12.850    419
# (12.952, 14.632]  13.716193  13.000  14.600    352
# (14.632, 16.312]  15.495976  14.650  16.250    410
# (16.312, 17.991]  17.172672  16.350  17.850    408
# (17.991, 19.671]  18.838005  18.000  19.600    396
# ...
